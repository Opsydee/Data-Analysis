# %%
import pandas as pd

# %% [markdown]
# ### 1. Importing the Data

# %%
C=pd.read_csv(r"C:\Users\Opsydee\Downloads\Supermart Grocery Sales - Retail Analytics Dataset.csv")

# %%
C
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %%
print(C.to_string())
# Out:
#      Order ID Customer Name           Category        Sub Category            City  Order Date   Region  Sales  Discount   Profit       State
# 0         OD1        Harish       Oil & Masala             Masalas         Vellore  11-08-2017    North   1254      0.12   401.28  Tamil Nadu
# 1         OD2         Sudha          Beverages       Health Drinks     Krishnagiri  11-08-2017    South    749      0.18   149.80  Tamil Nadu
# 2         OD3       Hussain        Food Grains        Atta & Flour      Perambalur  06-12-2017     West   2360      0.21   165.20  Tamil Nadu
# 3         OD4       Jackson   Fruits & Veggies    Fresh Vegetables      Dharmapuri  10-11-2016    South    896      0.25    89.60  Tamil Nadu
# 4         OD5       Ridhesh        Food Grains     Organic Staples            Ooty  10-11-2016    South   2355      0.26   918.45  Tamil Nadu
# ...

# %%
C
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %% [markdown]
# ### 2. Basic Information about the DataFrame

# %%
len(C)
# Out:
# 9994

# %%
C.count()
# Out:
# Order ID         9994
# Customer Name    9994
# Category         9994
# Sub Category     9994
# City             9994
# Order Date       9994
# Region           9994
# Sales            9994
# Discount         9994
# Profit           9994
# State            9994
# dtype: int64

# %%
C.head()
# Out:
#   Order ID Customer Name          Category      Sub Category         City  \
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1  11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2  06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3  10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4  10-11-2016  South   2355      0.26  918.45  Tamil Nadu

# %%
C.head(10)
# Out:
#   Order ID Customer Name          Category      Sub Category            City  \
# 0      OD1        Harish      Oil & Masala           Masalas         Vellore
# 1      OD2         Sudha         Beverages     Health Drinks     Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour      Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables      Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples            Ooty
# 5      OD6        Adavan       Food Grains   Organic Staples      Dharmapuri
# 6      OD7         Jonas  Fruits & Veggies  Fresh Vegetables          Trichy
# 7      OD8         Hafiz  Fruits & Veggies      Fresh Fruits  Ramanadhapuram
# 8      OD9         Hafiz            Bakery          Biscuits     Tirunelveli
# 9     OD10      Krithika            Bakery             Cakes         Chennai
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# ...

# %%
C.tail()
# Out:
#      Order ID Customer Name           Category  Sub Category         City  \
# 9989   OD9990        Sudeep  Eggs, Meat & Fish          Eggs      Madurai
# 9990   OD9991          Alan             Bakery      Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains          Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala        Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains  Atta & Flour  Tirunelveli
#
#       Order Date Region  Sales  Discount  Profit       State
# 9989  12/24/2015   West    945      0.16  359.10  Tamil Nadu
# 9990  07-12-2015   West   1195      0.26   71.70  Tamil Nadu
# 9991  06-06-2017   West   1567      0.16  501.44  Tamil Nadu
# 9992  10/16/2018   West   1659      0.15  597.24  Tamil Nadu
# 9993   4/17/2018   West   1034      0.28  165.44  Tamil Nadu

# %%
C.tail(10)
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 9984   OD9985       Willams       Oil & Masala           Masalas       Trichy
# 9985   OD9986         Shree  Eggs, Meat & Fish            Mutton  Kanyakumari
# 9986   OD9987          Peer             Bakery          Biscuits      Vellore
# 9987   OD9988        Ganesh   Fruits & Veggies  Fresh Vegetables        Theni
# 9988   OD9989       Jackson             Snacks           Cookies      Vellore
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
#       Order Date Region  Sales  Discount  Profit       State
# ...

# %%
C.sample()
# Out:
#      Order ID Customer Name           Category Sub Category   City  \
# 8053   OD8054      Veronica  Eggs, Meat & Fish      Chicken  Theni
#
#       Order Date Region  Sales  Discount  Profit       State
# 8053  11/21/2016   West    745      0.35  111.75  Tamil Nadu

# %%
C.sample(5)
# Out:
#      Order ID Customer Name           Category        Sub Category  \
# 5326   OD5327        Muneer   Fruits & Veggies  Organic Vegetables
# 4794   OD4795           Ram   Fruits & Veggies        Fresh Fruits
# 4352   OD4353        Adavan  Eggs, Meat & Fish              Mutton
# 1397   OD1398       Hussain          Beverages       Health Drinks
# 2209   OD2210         Aditi   Fruits & Veggies      Organic Fruits
#
#             City  Order Date Region  Sales  Discount  Profit       State
# 5326      Trichy   5/22/2017   East   1318      0.32  171.34  Tamil Nadu
# 4794     Chennai  11-12-2017   West    876      0.31  122.64  Tamil Nadu
# 4352       Theni  05-10-2015   West    950      0.18  199.50  Tamil Nadu
# 1397  Pudukottai   7/22/2015   West   1188      0.18  154.44  Tamil Nadu
# 2209  Coimbatore   9/21/2015   East   2225      0.12  689.75  Tamil Nadu

# %%
C.columns
# Out:
# Index(['Order ID', 'Customer Name', 'Category', 'Sub Category', 'City',
#        'Order Date', 'Region', 'Sales', 'Discount', 'Profit', 'State'],
#       dtype='object')

# %%
C. shape
# Out:
# (9994, 11)

# %%
C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Customer Name  9994 non-null   object
#  2   Category       9994 non-null   object
#  3   Sub Category   9994 non-null   object
#  4   City           9994 non-null   object
#  5   Order Date     9994 non-null   object
#  6   Region         9994 non-null   object
#  7   Sales          9994 non-null   int64
#  8   Discount       9994 non-null   float64
#  9   Profit         9994 non-null   float64
#  10  State          9994 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 859.0+ KB

# %%
C.describe()
# Out:
#              Sales     Discount       Profit
# count  9994.000000  9994.000000  9994.000000
# mean   1496.596158     0.226817   374.937082
# std     577.559036     0.074636   239.932881
# min     500.000000     0.100000    25.250000
# 25%    1000.000000     0.160000   180.022500
# 50%    1498.000000     0.230000   320.780000
# 75%    1994.750000     0.290000   525.627500
# max    2500.000000     0.350000  1120.950000

# %%
C.describe().T
# Out:
#            count         mean         std     min        25%      50%  \
# Sales     9994.0  1496.596158  577.559036  500.00  1000.0000  1498.00
# Discount  9994.0     0.226817    0.074636    0.10     0.1600     0.23
# Profit    9994.0   374.937082  239.932881   25.25   180.0225   320.78
#
#                 75%      max
# Sales     1994.7500  2500.00
# Discount     0.2900     0.35
# Profit     525.6275  1120.95

# %%
C["Order Date"].head(30)
# Out:
# 0     11-08-2017
# 1     11-08-2017
# 2     06-12-2017
# 3     10-11-2016
# 4     10-11-2016
# 5     06-09-2015
# 6     06-09-2015
# 7     06-09-2015
# 8     06-09-2015
# 9     06-09-2015
# 10    06-09-2015
# 11    06-09-2015
# 12     4/15/2018
# 13    12-05-2017
# 14    11/22/2016
# 15    11/22/2016
# 16    11-11-2015
# 17     5/13/2015
# 18     8/27/2015
# 19     8/27/2015
# 20     8/27/2015
# 21    12-09-2017
# 22    12-09-2017
# 23     7/16/2018
# 24     9/25/2016
# 25     1/16/2017
# 26     1/16/2017
# 27     9/17/2016
# 28     9/17/2016
# 29     9/17/2016
# Name: Order Date, dtype: object

# %%
C["Order Date"]=C["Order Date"].str.replace("/", "-")

# %%
C["Order Date"].head(30)
# Out:
# 0     11-08-2017
# 1     11-08-2017
# 2     06-12-2017
# 3     10-11-2016
# 4     10-11-2016
# 5     06-09-2015
# 6     06-09-2015
# 7     06-09-2015
# 8     06-09-2015
# 9     06-09-2015
# 10    06-09-2015
# 11    06-09-2015
# 12     4-15-2018
# 13    12-05-2017
# 14    11-22-2016
# 15    11-22-2016
# 16    11-11-2015
# 17     5-13-2015
# 18     8-27-2015
# 19     8-27-2015
# 20     8-27-2015
# 21    12-09-2017
# 22    12-09-2017
# 23     7-16-2018
# 24     9-25-2016
# 25     1-16-2017
# 26     1-16-2017
# 27     9-17-2016
# 28     9-17-2016
# 29     9-17-2016
# Name: Order Date, dtype: object

# %%
C["Order Date"].sample(30)
# Out:
# 7871    12-19-2017
# 734      1-21-2018
# 9625    11-04-2017
# 4627    09-04-2018
# 1511     3-27-2018
# 127     11-05-2018
# 4981    11-02-2016
# 773      1-30-2018
# 2653    12-13-2015
# 7142    09-02-2018
# 2738    10-28-2017
# 3775    12-26-2015
# 8936    06-12-2017
# 8364     8-21-2017
# 8840     6-26-2017
# 8674    10-17-2017
# 7161     9-15-2018
# 9065    12-28-2018
# 3567    09-12-2016
# 7115     9-22-2018
# 700      5-14-2016
# 4166    01-08-2017
# 9483    10-19-2018
# 8650     9-20-2017
# 8655    11-03-2016
# 9988    11-03-2016
# 2447    07-05-2015
# 6207     9-24-2017
# 8063     8-15-2017
# 227     08-09-2016
# Name: Order Date, dtype: object

# %%
C["Order Date"] = pd.to_datetime(C["Order Date"], format ="%m-%d-%Y")

# %%
C
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %%
C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Customer Name  9994 non-null   object
#  2   Category       9994 non-null   object
#  3   Sub Category   9994 non-null   object
#  4   City           9994 non-null   object
#  5   Order Date     9994 non-null   datetime64[ns]
#  6   Region         9994 non-null   object
#  7   Sales          9994 non-null   int64
#  8   Discount       9994 non-null   float64
#  9   Profit         9994 non-null   float64
#  10  State          9994 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 859.0+ KB

# %%
C["Order Date"].dt.year
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2016
# 4       2016
#         ...
# 9989    2015
# 9990    2015
# 9991    2017
# 9992    2018
# 9993    2018
# Name: Order Date, Length: 9994, dtype: int32

# %%
C["Day"] = C["Order Date"].dt.day_name()

# %%
C["Day"]
# Out:
# 0       Wednesday
# 1       Wednesday
# 2          Monday
# 3         Tuesday
# 4         Tuesday
#           ...
# 9989     Thursday
# 9990       Sunday
# 9991      Tuesday
# 9992      Tuesday
# 9993      Tuesday
# Name: Day, Length: 9994, dtype: object

# %%
C["Month"] = C["Order Date"].dt.month_name()

# %%
C["Month"]
# Out:
# 0       November
# 1       November
# 2           June
# 3        October
# 4        October
#           ...
# 9989    December
# 9990        July
# 9991        June
# 9992     October
# 9993       April
# Name: Month, Length: 9994, dtype: object

# %%
C["Year"] = C["Order Date"].dt.year

# %%
C["Year"]
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2016
# 4       2016
#         ...
# 9989    2015
# 9990    2015
# 9991    2017
# 9992    2018
# 9993    2018
# Name: Year, Length: 9994, dtype: int32

# %%
C
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %% [markdown]
# ### 3. Checking and dealing with the Null value and duplicate value

# %%
C.isnull()
# Out:
#       Order ID  Customer Name  Category  Sub Category   City  Order Date  \
# 0        False          False     False         False  False       False
# 1        False          False     False         False  False       False
# 2        False          False     False         False  False       False
# 3        False          False     False         False  False       False
# 4        False          False     False         False  False       False
# ...        ...            ...       ...           ...    ...         ...
# 9989     False          False     False         False  False       False
# 9990     False          False     False         False  False       False
# 9991     False          False     False         False  False       False
# 9992     False          False     False         False  False       False
# 9993     False          False     False         False  False       False
#
#       Region  Sales  Discount  Profit  State    Day  Month   Year
# ...

# %%
C.isna()
# Out:
#       Order ID  Customer Name  Category  Sub Category   City  Order Date  \
# 0        False          False     False         False  False       False
# 1        False          False     False         False  False       False
# 2        False          False     False         False  False       False
# 3        False          False     False         False  False       False
# 4        False          False     False         False  False       False
# ...        ...            ...       ...           ...    ...         ...
# 9989     False          False     False         False  False       False
# 9990     False          False     False         False  False       False
# 9991     False          False     False         False  False       False
# 9992     False          False     False         False  False       False
# 9993     False          False     False         False  False       False
#
#       Region  Sales  Discount  Profit  State    Day  Month   Year
# ...

# %%
C.isna().sum()
# Out:
# Order ID         0
# Customer Name    0
# Category         0
# Sub Category     0
# City             0
# Order Date       0
# Region           0
# Sales            0
# Discount         0
# Profit           0
# State            0
# Day              0
# Month            0
# Year             0
# dtype: int64

# %%
C.isna().any()
# Out:
# Order ID         False
# Customer Name    False
# Category         False
# Sub Category     False
# City             False
# Order Date       False
# Region           False
# Sales            False
# Discount         False
# Profit           False
# State            False
# Day              False
# Month            False
# Year             False
# dtype: bool

# %%
any(C.isnull().sum())
# Out:
# False

# %%
C.isna().sum().any()
# Out:
# False

# %%
C[C["Order ID"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Customer Name, Category, Sub Category, City, Order Date, Region, Sales, Discount, Profit, State, Day, Month, Year]
# Index: []

# %%
C[C.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Order ID, Customer Name, Category, Sub Category, City, Order Date, Region, Sales, Discount, Profit, State, Day, Month, Year]
# Index: []

# %%
# How to drop and fill missing data
#C.dropna()
#C.fillna(0)

# %%
C.duplicated().any()
# Out:
# False

# %%
C.drop_duplicates()
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %%
C = C.drop(columns = "State")

# %%
C
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %%
#C.drop("State", axis =1)

# %% [markdown]
# ### 4. Unique Value and Frequency count

# %%
C["Customer Name"].unique()
# Out:
# array(['Harish', 'Sudha', 'Hussain', 'Jackson', 'Ridhesh', 'Adavan',
#        'Jonas', 'Hafiz', 'Krithika', 'Ganesh', 'Yadav', 'Sharon', 'Peer',
#        'Sundar', 'Ramesh', 'Alan', 'Arutra', 'Haseena', 'Verma', 'Muneer',
#        'Veronica', 'Shah', 'Mathew', 'Akash', 'Anu', 'Sabeela', 'James',
#        'Willams', 'Malik', 'Amrish', 'Vince', 'Suresh', 'Esther', 'Yusuf',
#        'Komal', 'Veena', 'Shree', 'Roshan', 'Sudeep', 'Vinne', 'Vidya',
#        'Arvind', 'Kumar', 'Amy', 'Ravi', 'Sheeba', 'Ram', 'Rumaiza',
#        'Aditi', 'Surya'], dtype=object)

# %%
C["Customer Name"].nunique()
# Out:
# 50

# %%
C["Customer Name"].value_counts()
# Out:
# Customer Name
# Amrish      227
# Krithika    224
# Verma       218
# Arutra      218
# Vidya       215
# Shah        215
# Suresh      212
# Surya       209
# Harish      208
# Hussain     208
# Sudeep      207
# Komal       206
# Veena       205
# Mathew      205
# Adavan      205
# Ridhesh     204
# Muneer      204
# Peer        204
# Veronica    203
# Arvind      203
# Vinne       203
# Sharon      202
# Haseena     202
# Malik       201
# Yusuf       201
# Roshan      201
# Shree       200
# Ravi        200
# Jonas       198
# Alan        198
# James       197
# Ram         197
# Amy         196
# Akash       196
# Willams     195
# Sheeba      195
# Rumaiza     195
# Ganesh      193
# Esther      189
# Sudha       189
# Vince       188
# Ramesh      188
# Sabeela     188
# Sundar      187
# Aditi       187
# Anu         186
# Yadav       185
# Jackson     182
# Kumar       181
# Hafiz       174
# Name: count, dtype: int64

# %%
C["Sub Category"].nunique()
# Out:
# 23

# %%
C["Sub Category"].value_counts()
# Out:
# Sub Category
# Health Drinks         719
# Soft Drinks           681
# Cookies               520
# Breads & Buns         502
# Chocolates            499
# Noodles               495
# Masalas               463
# Biscuits              459
# Cakes                 452
# Edible Oil & Ghee     451
# Spices                447
# Mutton                394
# Eggs                  379
# Organic Staples       372
# Fresh Fruits          369
# Fish                  369
# Fresh Vegetables      354
# Atta & Flour          353
# Organic Fruits        348
# Chicken               348
# Organic Vegetables    347
# Dals & Pulses         343
# Rice                  330
# Name: count, dtype: int64

# %%
C["Day"].value_counts()
# Out:
# Day
# Tuesday      1933
# Saturday     1813
# Sunday       1724
# Monday       1628
# Wednesday    1261
# Friday       1091
# Thursday      544
# Name: count, dtype: int64

# %%
C["Year"].value_counts()
# Out:
# Year
# 2018    3312
# 2017    2587
# 2016    2102
# 2015    1993
# Name: count, dtype: int64

# %%
C["Month"].value_counts()
# Out:
# Month
# November     1471
# December     1408
# September    1383
# October       819
# May           735
# June          717
# July          710
# August        706
# March         696
# April         668
# January       381
# February      300
# Name: count, dtype: int64

# %%
for u in C.columns:
    print(u, "\n", C[u].unique())
# Out:
# Order ID
#  ['OD1' 'OD2' 'OD3' ... 'OD9992' 'OD9993' 'OD9994']
# Customer Name
#  ['Harish' 'Sudha' 'Hussain' 'Jackson' 'Ridhesh' 'Adavan' 'Jonas' 'Hafiz'
#  'Krithika' 'Ganesh' 'Yadav' 'Sharon' 'Peer' 'Sundar' 'Ramesh' 'Alan'
#  'Arutra' 'Haseena' 'Verma' 'Muneer' 'Veronica' 'Shah' 'Mathew' 'Akash'
#  'Anu' 'Sabeela' 'James' 'Willams' 'Malik' 'Amrish' 'Vince' 'Suresh'
#  'Esther' 'Yusuf' 'Komal' 'Veena' 'Shree' 'Roshan' 'Sudeep' 'Vinne'
#  'Vidya' 'Arvind' 'Kumar' 'Amy' 'Ravi' 'Sheeba' 'Ram' 'Rumaiza' 'Aditi'
#  'Surya']
# Category
#  ['Oil & Masala' 'Beverages' 'Food Grains' 'Fruits & Veggies' 'Bakery'
#  'Snacks' 'Eggs, Meat & Fish']
# Sub Category
#  ['Masalas' 'Health Drinks' 'Atta & Flour' 'Fresh Vegetables'
#  'Organic Staples' 'Fresh Fruits' 'Biscuits' 'Cakes' 'Chocolates' 'Eggs'
#  'Cookies' 'Chicken' 'Edible Oil & Ghee' 'Mutton' 'Soft Drinks'
#  'Dals & Pulses' 'Organic Vegetables' 'Noodles' 'Organic Fruits' 'Fish'
#  'Spices' 'Rice' 'Breads & Buns']
# City
# ...

# %%
pd.crosstab(C["Category"], C["Day"])
# Out:
# Day                Friday  Monday  Saturday  Sunday  Thursday  Tuesday  \
# Category
# Bakery                155     216       271     237        95      273
# Beverages             144     225       280     231        67      272
# Eggs, Meat & Fish     168     234       261     255        74      299
# Food Grains           157     223       249     243        77      272
# Fruits & Veggies      164     252       255     239        71      266
# Oil & Masala          148     230       242     246        77      261
# Snacks                155     248       255     273        83      290
#
# Day                Wednesday
# Category
# Bakery                   166
# Beverages                181
# Eggs, Meat & Fish        199
# Food Grains              177
# Fruits & Veggies         171
# Oil & Masala             157
# Snacks                   210

# %%
pd.crosstab(C["Category"], C["Day"], margins = True)
# Out:
# Day                Friday  Monday  Saturday  Sunday  Thursday  Tuesday  \
# Category
# Bakery                155     216       271     237        95      273
# Beverages             144     225       280     231        67      272
# Eggs, Meat & Fish     168     234       261     255        74      299
# Food Grains           157     223       249     243        77      272
# Fruits & Veggies      164     252       255     239        71      266
# Oil & Masala          148     230       242     246        77      261
# Snacks                155     248       255     273        83      290
# All                  1091    1628      1813    1724       544     1933
#
# Day                Wednesday   All
# Category
# Bakery                   166  1413
# Beverages                181  1400
# Eggs, Meat & Fish        199  1490
# Food Grains              177  1398
# Fruits & Veggies         171  1418
# Oil & Masala             157  1361
# Snacks                   210  1514
# ...

# %%
pd.crosstab(C["Category"], C["Day"], margins = True,margins_name ="Total" )
# Out:
# Day                Friday  Monday  Saturday  Sunday  Thursday  Tuesday  \
# Category
# Bakery                155     216       271     237        95      273
# Beverages             144     225       280     231        67      272
# Eggs, Meat & Fish     168     234       261     255        74      299
# Food Grains           157     223       249     243        77      272
# Fruits & Veggies      164     252       255     239        71      266
# Oil & Masala          148     230       242     246        77      261
# Snacks                155     248       255     273        83      290
# Total                1091    1628      1813    1724       544     1933
#
# Day                Wednesday  Total
# Category
# Bakery                   166   1413
# Beverages                181   1400
# Eggs, Meat & Fish        199   1490
# Food Grains              177   1398
# Fruits & Veggies         171   1418
# Oil & Masala             157   1361
# Snacks                   210   1514
# ...

# %%
D = pd.crosstab(C["Month"], C["Year"], margins = True, margins_name = "Totals")

print(D)
# Out:
# Year       2015  2016  2017  2018  Totals
# Month
# April       135   160   170   203     668
# August      153   159   176   218     706
# December    278   316   352   462    1408
# February     46    64    83   107     300
# January      79    58    89   155     381
# July        143   140   201   226     710
# June        135   138   199   245     717
# March       157   138   163   238     696
# May         122   146   225   242     735
# November    318   324   370   459    1471
# October     159   166   196   298     819
# September   268   293   363   459    1383
# Totals     1993  2102  2587  3312    9994

# %%
D.sort_values(by="Totals",ascending=False)
# Out:
# Year       2015  2016  2017  2018  Totals
# Month
# Totals     1993  2102  2587  3312    9994
# November    318   324   370   459    1471
# December    278   316   352   462    1408
# September   268   293   363   459    1383
# October     159   166   196   298     819
# May         122   146   225   242     735
# June        135   138   199   245     717
# July        143   140   201   226     710
# August      153   159   176   218     706
# March       157   138   163   238     696
# April       135   160   170   203     668
# January      79    58    89   155     381
# February     46    64    83   107     300

# %% [markdown]
# ### 5. Basic Operation

# %%
C["Profit"].mean()
# Out:
# 374.9370822493496

# %%
 round(C["Profit"].mean(),2)
# Out:
# 374.94

# %%
C.Profit.sum()
# Out:
# 3747121.1999999997

# %%
C.Sales.sum()
# Out:
# 14956982

# %%
C.Sales.sum() - C.Profit.sum()
# Out:
# 11209860.8

# %%
C["Expenses"]=C.Sales - C.Profit

# %%
C
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %%
C.Profit.sum()/C.Sales.sum()
# Out:
# 0.25052655676125035

# %%
C.Profit/C.Sales
# Out:
# 0       0.32
# 1       0.20
# 2       0.07
# 3       0.10
# 4       0.39
#         ...
# 9989    0.38
# 9990    0.06
# 9991    0.32
# 9992    0.36
# 9993    0.16
# Length: 9994, dtype: float64

# %%
C.Sales.argmax()
# Out:
# 267

# %%
C.Sales.idxmax()
# Out:
# 267

# %%
C.iloc[267]
# Out:
# Order ID                       OD268
# Customer Name                 Arvind
# Category                Oil & Masala
# Sub Category                 Masalas
# City                    Virudhunagar
# Order Date       2017-01-22 00:00:00
# Region                          East
# Sales                           2500
# Discount                        0.33
# Profit                         425.0
# Day                           Sunday
# Month                        January
# Year                            2017
# Expenses                      2075.0
# Name: 267, dtype: object

# %%
C.Sales.max()
# Out:
# 2500

# %%
C.Profit.argmax()
# Out:
# 3159

# %%
C.iloc[3159]
# Out:
# Order ID                      OD3160
# Customer Name                Haseena
# Category                      Bakery
# Sub Category                   Cakes
# City                          Cumbum
# Order Date       2017-09-04 00:00:00
# Region                       Central
# Sales                           2491
# Discount                        0.26
# Profit                       1120.95
# Day                           Monday
# Month                      September
# Year                            2017
# Expenses                     1370.05
# Name: 3159, dtype: object

# %%
C.Profit.max()
# Out:
# 1120.95

# %% [markdown]
# ### 6. Data Selection and filtering

# %%
C[["Sub Category","Category"]]
# Out:
#           Sub Category           Category
# 0              Masalas       Oil & Masala
# 1        Health Drinks          Beverages
# 2         Atta & Flour        Food Grains
# 3     Fresh Vegetables   Fruits & Veggies
# 4      Organic Staples        Food Grains
# ...                ...                ...
# 9989              Eggs  Eggs, Meat & Fish
# 9990          Biscuits             Bakery
# 9991              Rice        Food Grains
# 9992            Spices       Oil & Masala
# 9993      Atta & Flour        Food Grains
#
# [9994 rows x 2 columns]

# %%
C[C["Profit"]> 375]
# Out:
#      Order ID Customer Name           Category     Sub Category         City  \
# 0         OD1        Harish       Oil & Masala          Masalas      Vellore
# 4         OD5       Ridhesh        Food Grains  Organic Staples         Ooty
# 9        OD10      Krithika             Bakery            Cakes      Chennai
# 10       OD11        Ganesh             Snacks       Chocolates        Karur
# 18       OD19       Haseena  Eggs, Meat & Fish           Mutton      Tenkasi
# ...       ...           ...                ...              ...          ...
# 9983   OD9984          Peer        Food Grains             Rice    Nagercoil
# 9985   OD9986         Shree  Eggs, Meat & Fish           Mutton  Kanyakumari
# 9988   OD9989       Jackson             Snacks          Cookies      Vellore
# 9991   OD9992          Ravi        Food Grains             Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala           Spices   Pudukottai
#
# ...

# %%
profit_mean =C.Profit.mean()

# %%
C[C["Profit"] >=profit_mean]
# Out:
#      Order ID Customer Name           Category     Sub Category         City  \
# 0         OD1        Harish       Oil & Masala          Masalas      Vellore
# 4         OD5       Ridhesh        Food Grains  Organic Staples         Ooty
# 9        OD10      Krithika             Bakery            Cakes      Chennai
# 10       OD11        Ganesh             Snacks       Chocolates        Karur
# 18       OD19       Haseena  Eggs, Meat & Fish           Mutton      Tenkasi
# ...       ...           ...                ...              ...          ...
# 9983   OD9984          Peer        Food Grains             Rice    Nagercoil
# 9985   OD9986         Shree  Eggs, Meat & Fish           Mutton  Kanyakumari
# 9988   OD9989       Jackson             Snacks          Cookies      Vellore
# 9991   OD9992          Ravi        Food Grains             Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala           Spices   Pudukottai
#
# ...

# %%
C[C["Customer Name"] =="Harish"]
# Out:
#      Order ID Customer Name           Category       Sub Category  \
# 0         OD1        Harish       Oil & Masala            Masalas
# 121     OD122        Harish             Bakery              Cakes
# 127     OD128        Harish       Oil & Masala             Spices
# 134     OD135        Harish          Beverages      Health Drinks
# 147     OD148        Harish   Fruits & Veggies   Fresh Vegetables
# ...       ...           ...                ...                ...
# 9484   OD9485        Harish             Bakery      Breads & Buns
# 9497   OD9498        Harish  Eggs, Meat & Fish               Eggs
# 9545   OD9546        Harish   Fruits & Veggies     Organic Fruits
# 9843   OD9844        Harish             Bakery              Cakes
# 9959   OD9960        Harish       Oil & Masala  Edible Oil & Ghee
#
#                 City Order Date   Region  Sales  Discount  Profit        Day  \
# 0            Vellore 2017-11-08    North   1254      0.12  401.28  Wednesday
# ...

# %%
C[C["Region"] =="North"]
# Out:
#   Order ID Customer Name      Category Sub Category     City Order Date  \
# 0      OD1        Harish  Oil & Masala      Masalas  Vellore 2017-11-08
#
#   Region  Sales  Discount  Profit        Day     Month  Year  Expenses
# 0  North   1254      0.12  401.28  Wednesday  November  2017    852.72

# %%
C[C["Month"] =="November"]
# Out:
#      Order ID Customer Name           Category       Sub Category  \
# 0         OD1        Harish       Oil & Masala            Masalas
# 1         OD2         Sudha          Beverages      Health Drinks
# 14       OD15        Sundar  Eggs, Meat & Fish            Chicken
# 15       OD16        Ramesh       Oil & Masala  Edible Oil & Ghee
# 16       OD17          Alan             Bakery              Cakes
# ...       ...           ...                ...                ...
# 9960   OD9961        Amrish  Eggs, Meat & Fish             Mutton
# 9967   OD9968         Akash  Eggs, Meat & Fish            Chicken
# 9975   OD9976        Mathew          Beverages      Health Drinks
# 9985   OD9986         Shree  Eggs, Meat & Fish             Mutton
# 9988   OD9989       Jackson             Snacks            Cookies
#
#              City Order Date   Region  Sales  Discount  Profit        Day  \
# 0         Vellore 2017-11-08    North   1254      0.12  401.28  Wednesday
# ...

# %% [markdown]
# ### 7. Statistical Analysis

# %%
C[["Sales", "Profit"]].corr()
# Out:
#            Sales    Profit
# Sales   1.000000  0.605349
# Profit  0.605349  1.000000

# %%
#statistical Analysis
# correlation = Strength and direction,  the answer will either be -1 or 1
 
C[["Sales", "Profit"]].cov()
# Out:
#                 Sales        Profit
# Sales   333574.440317  83886.420833
# Profit   83886.420833  57567.787540

# %% [markdown]
# ### 8. Group Analysis: groupby() and Aggregation

# %%
cs=C.groupby("Customer Name")["Profit"].sum().sort_values(ascending=False)

# %%
cs.head(10)
# Out:
# Customer Name
# Arutra      87572.40
# Vidya       86725.64
# Krithika    85633.03
# Akash       82121.26
# Surya       80996.85
# Amrish      80191.89
# Vinne       79873.12
# Amy         79159.94
# Harish      79107.83
# Verma       79096.53
# Name: Profit, dtype: float64

# %%
d=C.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False)

# %%
d.head(10)
# Out:
# Customer Name
# Krithika    334361
# Amrish      333351
# Verma       331665
# Arutra      325720
# Vidya       321798
# Vinne       319565
# Shah        318588
# Suresh      315973
# Adavan      315341
# Surya       312645
# Name: Sales, dtype: int64

# %%
C.groupby("Customer Name").agg({"Profit":"sum","Discount":"sum","Sales":"sum"}).sort_values(by = "Discount",ascending = False)
# Out:
#                  Profit  Discount   Sales
# Customer Name
# Verma          79096.53     52.16  331665
# Amrish         80191.89     51.37  333351
# Shah           73786.22     49.59  318588
# Krithika       85633.03     48.64  334361
# Arutra         87572.40     48.43  325720
# Hussain        72354.97     48.24  307337
# Sudeep         75727.78     47.85  309196
# Muneer         76379.35     47.82  311553
# Vidya          86725.64     47.74  321798
# Veena          73953.52     47.61  299160
# Mathew         78888.56     47.37  308376
# Surya          80996.85     46.98  312645
# Vinne          79873.12     46.96  319565
# Harish         79107.83     46.44  293839
# Veronica       76884.93     46.37  301611
# Roshan         73299.12     46.33  298463
# Suresh         77450.88     46.19  315973
# Haseena        73167.14     45.98  298924
# Adavan         78044.29     45.94  315341
# Sheeba         78378.75     45.81  308720
# Sharon         76070.13     45.62  289486
# ...

# %%
C.groupby("Category").agg({"Sales":"sum","Profit":"sum"}).sort_values(by ="Profit",ascending = False)
# Out:
#                      Sales     Profit
# Category
# Snacks             2237546  568178.85
# Eggs, Meat & Fish  2267401  567357.22
# Fruits & Veggies   2100727  530400.38
# Food Grains        2115272  529162.64
# Bakery             2112281  528521.06
# Beverages          2085313  525605.76
# Oil & Masala       2038442  497895.29

# %%
C.groupby("Region")["Sales"].sum().sort_values(ascending = False)
# Out:
# Region
# West       4798743
# East       4248368
# Central    3468156
# South      2440461
# North         1254
# Name: Sales, dtype: int64

# %%
C.groupby("Year").agg({"Sales":"sum","Profit":"sum","Discount":"sum"}).sort_values(by = "Profit", ascending = False)
# Out:
#         Sales      Profit  Discount
# Year
# 2018  4977512  1244182.88    744.65
# 2017  3871912   953216.22    588.19
# 2016  3131959   797192.99    477.91
# 2015  2975599   752529.11    456.06

# %%
C.groupby("Month").agg({"Sales":"sum","Profit":"sum","Discount":"sum"}).sort_values(by="Profit", ascending = False)
# Out:
#              Sales     Profit  Discount
# Month
# November   2193924  556048.05    335.07
# December   2088076  530036.44    316.60
# September  2064266  517788.56    314.17
# October    1243289  309376.90    186.20
# July       1089385  274594.57    163.20
# March      1053980  267347.33    158.66
# May        1086920  263643.40    165.16
# June       1057808  263296.16    164.01
# August     1046807  258912.09    159.77
# April       998453  247476.97    152.52
# January     577972  142518.52     85.74
# February    456102  116082.21     65.71

# %%
C.groupby("Month").agg({"Sales":"sum","Profit":"sum","Discount":"sum","Day":"count"}).sort_values(by="Profit", ascending = False)
# Out:
#              Sales     Profit  Discount   Day
# Month
# November   2193924  556048.05    335.07  1471
# December   2088076  530036.44    316.60  1408
# September  2064266  517788.56    314.17  1383
# October    1243289  309376.90    186.20   819
# July       1089385  274594.57    163.20   710
# March      1053980  267347.33    158.66   696
# May        1086920  263643.40    165.16   735
# June       1057808  263296.16    164.01   717
# August     1046807  258912.09    159.77   706
# April       998453  247476.97    152.52   668
# January     577972  142518.52     85.74   381
# February    456102  116082.21     65.71   300

# %%
C.groupby("Day").agg(
   Total_Sales = ("Sales", "sum"),
   Total_Profit = ("Profit", "sum"),
   Total_Discount = ("Discount", "sum"),
   Number_of_orders=("Day", "count")
).sort_values(by= "Total_Profit", ascending=False)
# Out:
#            Total_Sales  Total_Profit  Total_Discount  Number_of_orders
# Day
# Tuesday        2855751     716365.38          436.09              1933
# Saturday       2724409     685895.49          410.83              1813
# Sunday         2615647     654549.58          387.15              1724
# Monday         2428324     605581.72          373.63              1628
# Wednesday      1886849     468065.48          288.32              1261
# Friday         1638367     407132.68          243.90              1091
# Thursday        807635     209530.87          126.89               544

# %%
C.groupby(["Year","Month"])["Profit"].sum()
# Out:
# Year  Month
# 2015  April         51679.95
#       August        54424.99
#       December     103099.84
#       February      18125.94
#       January       32594.50
#       July          53604.46
#       June          51360.52
#       March         66572.78
#       May           37879.04
#       November     124528.77
#       October       63465.04
#       September     95193.28
# 2016  April         59001.65
#       August        58561.35
#       December     117760.26
#       February      24115.62
#       January       20487.32
#       July          56951.80
#       June          54424.72
#       March         58060.58
#       May           56158.91
#       November     121308.72
#       October       61509.91
#       September    108852.15
# 2017  April         59817.03
#       August        66637.41
#       December     135821.97
#       February      32683.32
#       January       29008.80
#       July          77383.36
#       June          69709.74
# ...

# %%
C.groupby(["Year","Month"])["Profit"].sum().sort_values(ascending = False)
# Out:
# Year  Month
# 2018  September    176698.83
#       November     175386.85
#       December     173354.37
# 2017  September    137044.30
#       December     135821.97
#       November     134823.71
# 2015  November     124528.77
# 2016  November     121308.72
#       December     117760.26
# 2018  October      115026.58
# 2016  September    108852.15
# 2015  December     103099.84
#       September     95193.28
# 2018  May           88614.25
#       June          87801.18
#       July          86654.95
#       March         82793.96
# 2017  May           80991.20
# 2018  August        79288.34
# 2017  July          77383.36
# 2018  April         76978.34
# 2017  June          69709.74
#       October       69375.37
#       August        66637.41
# 2015  March         66572.78
#       October       63465.04
# 2016  October       61509.91
# 2018  January       60427.90
# 2017  March         59920.01
#       April         59817.03
# 2016  April         59001.65
# ...

# %%
C.groupby(["Customer Name", "Category"])["Sales"].sum()
# Out:
# Customer Name  Category
# Adavan         Bakery               40517
#                Beverages            43145
#                Eggs, Meat & Fish    31216
#                Food Grains          43007
#                Fruits & Veggies     53665
#                                     ...
# Yusuf          Eggs, Meat & Fish    38375
#                Food Grains          39066
#                Fruits & Veggies     36500
#                Oil & Masala         62407
#                Snacks               53986
# Name: Sales, Length: 350, dtype: int64

# %%
C.pivot_table(index = "Customer Name", columns = "Category", values ="Sales", aggfunc ="sum" )
# Out:
# Category       Bakery  Beverages  Eggs, Meat & Fish  Food Grains  \
# Customer Name
# Adavan          40517      43145              31216        43007
# Aditi           54319      40575              33388        50051
# Akash           46433      36972              47451        57422
# Alan            40317      33244              39962        54495
# Amrish          63839      42617              36158        59157
# Amy             40098      52743              31185        49065
# Anu             22636      50962              57387        38537
# Arutra          51498      48469              52395        36988
# Arvind          43849      36105              39633        45652
# Esther          39248      35889              44908        39887
# Ganesh          39996      32942              30816        44957
# Hafiz           39179      27359              45156        34389
# Harish          43159      41913              44340        32260
# ...

# %%
C.pivot_table(index = "Customer Name", columns = "Category", values = "Profit", aggfunc ="sum")
# Out:
# Category         Bakery  Beverages  Eggs, Meat & Fish  Food Grains  \
# Customer Name
# Adavan          9585.97   11756.20            8260.30      8876.27
# Aditi          15340.57    9695.27            8419.65     12748.25
# Akash          12972.22   10592.39           11117.08     16186.18
# Alan            8215.32    9527.21            9405.97     14119.92
# Amrish         15756.67    9604.62            8919.34     13704.05
# Amy            10431.25   15327.23            8516.43     11044.16
# Anu             4848.59   11627.84           14933.33      9404.23
# Arutra         14021.40   12392.20           14134.62     11226.03
# Arvind         10295.10    8383.32           10503.06     12738.41
# Esther          8498.97    9384.24            9684.92     10074.42
# Ganesh         11484.12    8388.97            8497.90     11349.31
# Hafiz          10848.94    6689.70           12084.17      8657.28
# Harish         12198.48   10338.61           12391.85      8511.00
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# - Pandas: Built on Matplotlib, simplifies quick plotting directly from DataFrames
# - Seaborn: Built on Matplotlib simplifies complex statistics visalization and improves the statistics of the plots.
# - Matplotlib: The foundation of both pandas and seaborn visualization. it provides the core plotting functions., but with more flexibility at the cost of increased complexity

# %% [markdown]
# When to use each library
#
# - Pandas: when you need quick, basic visualizations dirctly from your Dataframe.
#
# - Matplotlib: when you need fine control and customization of plots or when creating more complex visualizations.
#
# - Seaborn: when you want aesthetically pleasing plots with less code andd when you are focusing on statistical relationships in the data

# %% [markdown]
# ## Most Commonly used Visuals
# -Bar Chart: Categorical comparison using rectangular bars
#    - when to use : Comparing different groups or categories (sales by region, products by popularity)
#    - Use for: Discrete Categories when you havve a few categories
# - Histogram: Distribution of a numeric variables using bars
#    - when to use: To observe the frequency distribution of data(e.g. age distribution,income ranges )
#    - Use for:Understand the spread or skewness of data
# - Line chart: Usually for time series data
#    - when to use: To show trends or changes over time (e.g. stock prices over Months)
#    - Use For: Tracking changes over a continuous intervals(Like time)
# - Scatter Plot: Points Plotted on two axes to display relationships between two variables.
#    - When to use: To show correlation or relationships between two numeric variables (e.g Sales vs Profit)
#    - Use For : identifying relationships clutters and outlier
# - Pie Chart: circular chart divided into slices to represent proportions
#    - when to use : To show parts of a whole (e.g market share,budget allocating)
#    - Use For: Simple proportional comparisons avoid with many categories.
# - Boxplot: Display distribution quartikes and outliers of data
#    - When to use: To compare distribution across categories (e.g profits across different product lines)
#    - Use For: Visualizing spread, outliers and comparing distributions particular with statistical data

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
C.groupby("Category")["Sales"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %%
C.groupby("Category")["Sales"].sum().sort_values (ascending = False).plot(kind="bar", title="Total Sales per Category", color ="black")
# Out:
# <Axes: title={'center': 'Total Sales per Category'}, xlabel='Category'>

# %%
C.groupby("Category")["Sales"].sum().sort_values (ascending = False).plot(kind="barh", title="Total Sales per Category", color ="yellow")
# Out:
# <Axes: title={'center': 'Total Sales per Category'}, ylabel='Category'>

# %%
C.groupby("Year")["Profit"].sum().plot(kind="barh", title="Profit by Year", color ="Red")
# Out:
# <Axes: title={'center': 'Profit by Year'}, ylabel='Year'>

# %%
FC = C.groupby("Category")["Sales"].sum().sort_values()
print(FC)
# Out:
# Category
# Oil & Masala         2038442
# Beverages            2085313
# Fruits & Veggies     2100727
# Bakery               2112281
# Food Grains          2115272
# Snacks               2237546
# Eggs, Meat & Fish    2267401
# Name: Sales, dtype: int64

# %%
plt.bar(FC.index, FC.values, color="black")
plt.title("Sales by Category")
plt.ylabel("Total sales")
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Oil & Masala'),
#   Text(1, 0, 'Beverages'),
#   Text(2, 0, 'Fruits & Veggies'),
#   Text(3, 0, 'Bakery'),
#   Text(4, 0, 'Food Grains'),
#   Text(5, 0, 'Snacks'),
#   Text(6, 0, 'Eggs, Meat & Fish')])

# %%
y=C.groupby("Year")["Profit"].sum()

# %%
y
# Out:
# Year
# 2015     752529.11
# 2016     797192.99
# 2017     953216.22
# 2018    1244182.88
# Name: Profit, dtype: float64

# %%
plt.barh(y.index,y.values, color="cyan")
plt.title("Profit by Year")
plt.xlabel("Total Profit")
plt.yticks(y.index.astype(int)) # set the y-axis to displayonly integer values (years)
plt.show()

# %%
C.groupby("Category")["Sales"].sum().plot(kind="bar", color ="black",title="Sales by category")
plt.ylabel("Total sales")
# Out:
# Text(0, 0.5, 'Total sales')

# %%
sns.barplot(x="Category", y ="Sales", data=C, estimator = sum)
plt.title("Total sales per Category (seaborn)")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Oil & Masala'),
#   Text(1, 0, 'Beverages'),
#   Text(2, 0, 'Food Grains'),
#   Text(3, 0, 'Fruits & Veggies'),
#   Text(4, 0, 'Bakery'),
#   Text(5, 0, 'Snacks'),
#   Text(6, 0, 'Eggs, Meat & Fish')])

# %%
sns.barplot(x="Region", y="Profit", data=C,estimator=sum, palette ="cool")
plt.title("Profit per region (Seaborn)")
plt.xticks(rotation=45)
# Out:
# C:\Users\Opsydee\AppData\Local\Temp\ipykernel_1800\2626141843.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Region", y="Profit", data=C,estimator=sum, palette ="cool")
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'North'),
#   Text(1, 0, 'South'),
#   Text(2, 0, 'West'),
#   Text(3, 0, 'Central'),
#   Text(4, 0, 'East')])

# %%
C.groupby("Order Date")["Sales"].sum().plot(kind="line", title= "Sales over Time", color="orange")
plt.ylabel("Total sales")
plt.xlabel("Order Date")
# Out:
# Text(0.5, 0, 'Order Date')

# %%
C.groupby("Month")["Sales"].sum().plot(kind="line", title= "Sales over Time", color="orange")
plt.ylabel("Total sales")
plt.xlabel("Order Date")
# Out:
# Text(0.5, 0, 'Order Date')

# %%
C.groupby("Year")["Sales"].sum().plot(kind="line", title= "Sales over Time", color="orange")
plt.ylabel("Total sales")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
C.groupby("Day")["Sales"].sum().plot(kind="line", title= "Sales over Time", color="orange")
plt.ylabel("Total sales")
plt.xlabel("Order Date")
plt.xticks(rotation=45)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.]),
#  [Text(-1.0, 0, 'Wednesday'),
#   Text(0.0, 0, 'Friday'),
#   Text(1.0, 0, 'Monday'),
#   Text(2.0, 0, 'Saturday'),
#   Text(3.0, 0, 'Sunday'),
#   Text(4.0, 0, 'Thursday'),
#   Text(5.0, 0, 'Tuesday'),
#   Text(6.0, 0, 'Wednesday'),
#   Text(7.0, 0, '')])

# %%
#Matplotlib
Sales_Over_time = C.groupby("Order Date")["Sales"].sum()
plt.plot(Sales_Over_time.index, Sales_Over_time.values, color="red")
plt.title("Sales Over Time")
plt.ylabel("Total Sales")
plt.xlabel("Order Date")
plt.xticks(rotation=45)
plt.show()

# %%
#seaborn
Sales_Over_time = C.groupby("Order Date")["Sales"].sum().reset_index()
sns.lineplot(x="Order Date", y="Sales", data= Sales_Over_time)# color="orange")
plt.title("Sales Over Time")
plt.xticks(rotation=45)
# Out:
# (array([16436., 16617., 16801., 16983., 17167., 17348., 17532., 17713.,
#         17897.]),
#  [Text(16436.0, 0, '2015-01'),
#   Text(16617.0, 0, '2015-07'),
#   Text(16801.0, 0, '2016-01'),
#   Text(16983.0, 0, '2016-07'),
#   Text(17167.0, 0, '2017-01'),
#   Text(17348.0, 0, '2017-07'),
#   Text(17532.0, 0, '2018-01'),
#   Text(17713.0, 0, '2018-07'),
#   Text(17897.0, 0, '2019-01')])

# %%
#histogram - pandas
C["Discount"].plot(kind="hist",bins=10,title="Discount Distribution",color="green")
# Out:
# <Axes: title={'center': 'Discount Distribution'}, ylabel='Frequency'>

# %%
#matplotlib
plt.hist(C["Discount"], bins=10,color="green")
plt.title("Discount Distribution")
plt.xlabel("Discount")
# Out:
# Text(0.5, 0, 'Discount')

# %%
sns.histplot(C["Discount"], bins=10, color="green")
plt.title("Discount Distribution")
# Out:
# Text(0.5, 1.0, 'Discount Distribution')

# %%
#scatter plot - pandas 
C.plot(kind="scatter", x="Sales", y="Profit", title="Sales vs Profit")
# Out:
# <Axes: title={'center': 'Sales vs Profit'}, xlabel='Sales', ylabel='Profit'>

# %%
plt.scatter(C["Sales"], C["Profit"], color="purple")
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %%
sns.scatterplot(x="Sales", y="Profit", data=C, color="purple")
plt.title("Sales vs Profit")
# Out:
# Text(0.5, 1.0, 'Sales vs Profit')

# %%
C.groupby("Region")["Sales"].sum().plot(kind="pie",title="Sales Distribution by Region",autopct="%1.1f%%")# startangle=90)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
sales_by_region=C.groupby("Region")["Sales"].sum()
plt.pie(sales_by_region, labels=sales_by_region.index, autopct="%1.1f%%",startangle=90)
plt.title("Sales Distribution by Region")
# Out:
# Text(0.5, 1.0, 'Sales Distribution by Region')

# %%
C.boxplot(column="Profit",by="Category")
plt.title("Profit by Category")
plt.suptitle("")
plt.xticks(rotation=45)
# Out:
# (array([1, 2, 3, 4, 5, 6, 7]),
#  [Text(1, 0, 'Bakery'),
#   Text(2, 0, 'Beverages'),
#   Text(3, 0, 'Eggs, Meat & Fish'),
#   Text(4, 0, 'Food Grains'),
#   Text(5, 0, 'Fruits & Veggies'),
#   Text(6, 0, 'Oil & Masala'),
#   Text(7, 0, 'Snacks')])

# %%
sns.boxplot(x="Category",y="Profit",data=C)
plt.title("Profit by Category")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Oil & Masala'),
#   Text(1, 0, 'Beverages'),
#   Text(2, 0, 'Food Grains'),
#   Text(3, 0, 'Fruits & Veggies'),
#   Text(4, 0, 'Bakery'),
#   Text(5, 0, 'Snacks'),
#   Text(6, 0, 'Eggs, Meat & Fish')])

# %%
corr=C[["Sales","Discount","Profit"]].corr()
print(corr)
# Out:
#              Sales  Discount    Profit
# Sales     1.000000 -0.005512  0.605349
# Discount -0.005512  1.000000  0.000017
# Profit    0.605349  0.000017  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
C.boxplot(column="Profit")
plt.title("Boxplot for profit")
# Out:
# Text(0.5, 1.0, 'Boxplot for profit')

# %%
C.boxplot(column="Discount")
plt.title("Boxplot for Discount")
# Out:
# Text(0.5, 1.0, 'Boxplot for Discount')

# %%
Q1 = C["Profit"].quantile(0.25)
Q3 = C["Profit"].quantile(0.75)
IQR = Q3 - Q1



print(Q1)
print(Q3)
print(IQR)
# Out:
# 180.0225
# 525.6275
# 345.605

# %%
outliers =C[(C["Profit"]<(Q3-1.5*IQR))| (C["Profit"]>(Q3-1.5*IQR))]

# %%
outliers.shape
# Out:
# (9994, 14)

# %%
outliers
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...
